# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#from scipy.interpolate import make_interp_spline
df = pd.DataFrame([[20,2863.2],[40,801.9],[60,448.7],[80,284.0],[100,210.4],[120,163.1],[140,134.4],[160,112.2],[180,104.0],[200,90.1]],columns=['Distance','Illuminance'])
#X_Y_Spline = make_interp_spline(df['Distance'], df['Illuminance'])
#X_ = np.linspace(df['Distance'].min(), df['Distance'].max(), 500)
#Y_ = X_Y_Spline(X_)
plt.plot(X_,Y_)
plt.xlabel('Distance (cm)')
plt.ylabel('Illuminance (lux)')
plt.yscale('log');

# %%
s = []
while True:
    a = float(input())
    b = float(input())
    s.append([a,b])
    print(s)
