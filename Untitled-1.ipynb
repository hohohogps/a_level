# %%
from sys import getsizeof
import matplotlib.pyplot as plt
import time
#set is hashed
dict = {}
s = set()
l = []
for i in range (0,5000000):
    #start = time.time()
    s.add(i)
    if getsizeof(s) not in list(dict.keys()):
        dict[getsizeof(s)] = 1
    else:
        dict[getsizeof(s)] += 1
    #print(time.time()-start)

plt.plot(list(dict.keys()),list(dict.values()))
